# %%
import urllib.request
import json
from pandas.io.json import json_normalize
import hashlib
import hmac
import base64
import pandas as pd
import requests


client_id = "jHb5_HTs7XQhAvYL6kc8"
client_secret = "UPiJNEX06J"

keyword = '이태원 학원' #키워드

display = 5 #한 번에 표시할 검색 결과 개수(기본값: 1, 최댓값: 5)
start = 1 #검색 시작 위치(기본값: 1, 최댓값: 1)
sort = 'random'
#검색 결과 정렬 방법 
#- random: 정확도순으로 내림차순 정렬(기본값) 
#- comment: 업체 및 기관에 대한 카페, 블로그의 리뷰 개수순으로 내림차순 정렬 



encText = urllib.parse.quote(keyword)
url = "https://openapi.naver.com/v1/search/local.json?query={}&display={}&start={}&sort={}".format(encText,display, start, sort) # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Sun, 30 Oct 2022 08:16:37 +0900",
# 	"total":5,
# 	"start":1,
# 	"display":5,
# 	"items":[
# 		{
# 			"title":"리탐빌 요가명상",
# 			"link":"http:\/\/www.ritamville.com\/",
# 			"category":"스포츠,레크레이션학원>요가,명상",
# 			"description":"",
# 			"telephone":"",
# 			"address":"서울특별시 용산구 이태원동 258-8",
# 			"roadAddress":"서울특별시 용산구 회나무로44길 2",
# 			"mapx":"311520",
# 			"mapy":"549204"
# 		},
# 		{
# 			"title":"BEK Lodge",
# 			"link":"http:\/\/www.bek.co.kr",
# 			"category":"어학원>영어학원",
# 			"description":"",
# 			"telephone":"",
# 			"address":"서울특별시 용산구 이태원동 36-85",
# 			"roadAddress":"서울특별시 용산구 녹사평대로26길 8",
# 			"mapx":"311065",
# 			"mapy":"548037"
# 		},
# 		{
# 			"title":"밀밀아",
# 			"link":"https:\/\/blog.naver.com\/milmilayoga",
# 			"category":"스포츠,레크레이션학원>요가,명상",
# 			"description":"",
# 			"telephone":"",
# 			"address":"서울특별시 용산구 이태원동 193-95 밀밀아",
# 			"roadAddress":"서울특별시 용산구 녹사평대로40나길 38-11 밀밀아",
# 			"mapx":"310880",
# 			"mapy":"548715"
# 		},
# 		{
# ...
