# %%
import urllib.request
import json
from pandas.io.json import json_normalize
import hashlib
import hmac
import base64
import pandas as pd
import requests

import requests
import pandas as pd
import numpy as np


REST_API = '61d325ab56c251b7a62a41a2cfb3b4d6'

def elec_location(region,page_num):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
    params = {'query': region,'page': page_num}
    headers = {"Authorization": "KakaoAK " + str(REST_API)}

    places = requests.get(url, params=params, headers=headers).json()['documents']
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    if total > 45:
        print(total,'개 중 45개 데이터밖에 가져오지 못했습니다!')
    else :
        print('모든 데이터를 가져왔습니다!')
    return places

def elec_info(places):
    X = []
    Y = []
    stores = []
    road_address = []
    place_url = []
    ID = []
    for place in places:
        X.append(float(place['x']))
        Y.append(float(place['y']))
        stores.append(place['place_name'])
        road_address.append(place['road_address_name'])
        place_url.append(place['place_url'])
        ID.append(place['id'])

    ar = np.array([ID,stores, X, Y, road_address,place_url]).T
    df = pd.DataFrame(ar, columns = ['ID','stores', 'X', 'Y','road_address','place_url'])
    return df

def keywords(location_name): #여러 개 키워드
    df = None 
    for loca in location:
        for page in range(1,4):
            local_name = elec_location(loca, page)
            local_elec_info = elec_info(local_name)

            if df is None:
                df = local_elec_info
            elif local_elec_info is None:
                continue
            else:
                df = pd.concat([df, local_elec_info],join='outer', ignore_index = True)
    return df


elec_location("서울 서대문구 연희동 수학학원", 1)
# Out:
# 211 개 중 45개 데이터밖에 가져오지 못했습니다!
# [{'address_name': '서울 서대문구 대신동 127-8',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '1740820332',
#   'phone': '010-8354-0930',
#   'place_name': '꿈쌤스터디',
#   'place_url': 'http://place.map.kakao.com/1740820332',
#   'road_address_name': '서울 서대문구 봉원사길 23',
#   'x': '126.946238415902',
#   'y': '37.5676500159583'},
#  {'address_name': '서울 서대문구 남가좌동 344-17',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '27506058',
#   'phone': '02-308-8410',
#   'place_name': '드림클래스',
#   'place_url': 'http://place.map.kakao.com/27506058',
#   'road_address_name': '서울 서대문구 거북골로 53-18',
#   'x': '126.922901024521',
#   'y': '37.5781516909197'},
#  {'address_name': '서울 서대문구 남가좌동 322-3',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '1319182258',
#   'phone': '02-302-3128',
#   'place_name': '하비스트수학',
#   'place_url': 'http://place.map.kakao.com/1319182258',
#   'road_address_name': '서울 서대문구 명지대1길 32',
#   'x': '126.923902528333',
#   'y': '37.5818662367251'},
#  {'address_name': '서울 서대문구 남가좌동 119-27',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '1840249158',
#   'phone': '02-304-3690',
#   'place_name': '최상위수학아이들',
#   'place_url': 'http://place.map.kakao.com/1840249158',
#   'road_address_name': '서울 서대문구 모래내로15길 40',
#   'x': '126.919985146608',
#   'y': '37.5735907193779'},
#  {'address_name': '서울 서대문구 남가좌동 119-28',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '175610456',
#   'phone': '02-6014-7515',
#   'place_name': '신동수학교습소',
#   'place_url': 'http://place.map.kakao.com/175610456',
#   'road_address_name': '서울 서대문구 모래내로15길 38',
#   'x': '126.92002147104',
#   'y': '37.5734970405491'},
#  {'address_name': '서울 서대문구 홍제동 361-95',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '1484576297',
#   'phone': '010-4895-2068',
#   'place_name': '피타수학교습소',
#   'place_url': 'http://place.map.kakao.com/1484576297',
#   'road_address_name': '서울 서대문구 홍제내2가길 23',
#   'x': '126.936239221908',
#   'y': '37.5860379352609'},
#  {'address_name': '서울 서대문구 홍제동 321-3',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '24505938',
#   'phone': '02-356-8810',
#   'place_name': '이젠수학교습소',
#   'place_url': 'http://place.map.kakao.com/24505938',
#   'road_address_name': '서울 서대문구 모래내로24길 13',
#   'x': '126.94394891246677',
#   'y': '37.583774048541535'},
#  {'address_name': '서울 서대문구 남가좌동 191-10',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '1715182548',
#   'phone': '',
#   'place_name': '가재울팩토센터수학교습소',
#   'place_url': 'http://place.map.kakao.com/1715182548',
#   'road_address_name': '서울 서대문구 모래내로15길 56',
#   'x': '126.9193325469154',
#   'y': '37.5741128521166'},
#  {'address_name': '서울 서대문구 남가좌동 191-22',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '338970120',
#   'phone': '',
#   'place_name': '빨간펜수학의달인 가재울점',
#   'place_url': 'http://place.map.kakao.com/338970120',
#   'road_address_name': '서울 서대문구 모래내로15길 60',
#   'x': '126.919178472151',
#   'y': '37.5742244700578'},
#  {'address_name': '서울 서대문구 남가좌동 190-9',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '176639970',
#   'phone': '02-3152-5678',
#   'place_name': 'e해법수학',
#   'place_url': 'http://place.map.kakao.com/176639970',
#   'road_address_name': '서울 서대문구 모래내로15길 62',
#   'x': '126.919091243516',
#   'y': '37.5742829749514'},
#  {'address_name': '서울 서대문구 남가좌동 184-12',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '541909803',
#   'phone': '02-304-5359',
#   'place_name': '이가수학',
#   'place_url': 'http://place.map.kakao.com/541909803',
#   'road_address_name': '서울 서대문구 거북골로 105',
#   'x': '126.91838291351716',
#   'y': '37.5750330157549'},
#  {'address_name': '서울 서대문구 남가좌동 5-92',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '426133685',
#   'phone': '02-308-5138',
#   'place_name': '신나는수학',
#   'place_url': 'http://place.map.kakao.com/426133685',
#   'road_address_name': '서울 서대문구 명지대3길 36',
#   'x': '126.921750177838',
#   'y': '37.5820243054088'},
#  {'address_name': '서울 서대문구 남가좌동 385',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '841014551',
#   'phone': '',
#   'place_name': '서채은 수학전문학원',
#   'place_url': 'http://place.map.kakao.com/841014551',
#   'road_address_name': '서울 서대문구 가재울미래로 2',
#   'x': '126.91764558484907',
#   'y': '37.5743477478958'},
#  {'address_name': '서울 서대문구 홍제동 317-3',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '1448468968',
#   'phone': '',
#   'place_name': '고은수학',
#   'place_url': 'http://place.map.kakao.com/1448468968',
#   'road_address_name': '서울 서대문구 통일로37길 50',
#   'x': '126.94390079878966',
#   'y': '37.58603281520326'},
#  {'address_name': '서울 은평구 응암동 247-102',
#   'category_group_code': 'AC5',
#   'category_group_name': '학원',
#   'category_name': '교육,학문 > 학원 > 수학학원',
#   'distance': '',
#   'id': '27514333',
#   'phone': '02-372-3064',
#   'place_name': '라온수학',
#   'place_url': 'http://place.map.kakao.com/27514333',
#   'road_address_name': '서울 은평구 가좌로7가길 25-55',
#   'x': '126.921867020909',
#   'y': '37.5839678251664'}]
