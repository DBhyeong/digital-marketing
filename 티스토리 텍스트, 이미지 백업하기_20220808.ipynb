# %%
import requests
from bs4 import BeautifulSoup
from bs4 import Comment
from PIL import Image
import re
import os

def tistory_backup(post_num):
    for num in range(1, post_num + 1):
        url = 'https://mvmv3754.tistory.com/' + str(num)
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'lxml')
        
        ### 포스팅 글 제목
        titles = soup.select_one('#content > div.inner > div.post-cover > div > h1')
        
        ### 등록일
        date = soup.select_one('#content > div.inner > div.post-cover > div > span.meta > span.date')
        
        if not titles or not date:
            continue
        
        print(titles.text)    
        print(date.text)
        
        ### 포스팅 내용
        entry_content = soup.find('div', {'class':'entry-content'})
        print(entry_content.get_text())
        
        res = requests.get(url)
        soup_img = BeautifulSoup(res.content, 'lxml')
        imgs = soup_img.select('img[src^=https]')  # https 로 시작하는 src, '//'로 시작하는 src 제외시킴
        print(f'이미지 수 : {len(imgs)}')
        # print(imgs)
        
        # 저장 디렉토리 만들기
        if not os.path.exists('tistoryBackup'):
            os.mkdir('tistoryBackup')
        if not os.path.exists('tistoryBackup/post_' + str(num)):
            os.makedirs('tistoryBackup/post_' + str(num))
        
        cnt = 1
        for img in imgs:
            img_url = img['src']
            
            ## pillow.Image로 이미지 format 알아내기
            imageObj = Image.open(requests.get(img_url, stream=True).raw)
            img_format = imageObj.format
            imge_size = imageObj.size
            print(f'img_url: {img_url}')
            print(f'img_format: {img_format}')
            print(f'imge_size: {imge_size}')
            print(f'os.path.basename(img_url): {os.path.basename(img_url)}')
            
            res_img = requests.get(img_url).content
            print(f'len(이미지): {len(res_img)}')  # requests의 .content는 bytes 타입을 리턴함
            
            if img_url.split('.')[-1] in ['png', 'jpg']:
                img_name = str(num) + '_' + str(cnt) + '_' + os.path.basename(img_url)
            else:
                img_name = str(num) + '_' + str(cnt) + '_' + 'no_filename_img.' + img_format
            
            print(img_name)
            
            if len(res_img) > 100:  # 이미지 용량이 00 bytes 이상인 것만
                with open('./tistoryBackup/post_' + str(num) + '/' + img_name, 'wb') as f:
                    f.write(res_img)
                cnt += 1
        
        title_content = titles.text + '\n' + date.text +  '\n' + entry_content.get_text()
        filename = str(num) + '_tistory_title_content.txt'
        with open('./tistoryBackup/post_' + str(num) + '/' + filename, 'w', encoding='utf-8') as f:
            f.write(title_content)
            
tistory_backup(1)
# Out:
# 항문에 피가 나는 이유(치질/치핵)
# 2021. 1. 24.
#
#
# 항문에서피가나는이유
# 우선  항문에서 피가나는 이유 중 가장 높은 확률이  치핵이라고 합니다. 평소 습관과 먹는 음식에 따라서 항문을 피로하게 할 경우 젊은 층에서도 충분히 자주 발생될 수 있는 질환인데요, 항문쪽에는 피가 지나가는 혈관이 풍부하게 자라고 있어 혹시나 항문에서 피가 날 경우 가까운 항문쪽 병원에 가는 것이 우선 바람직한 행동이랍니다.
#
#
# 치핵(치질)의 원인
# 불규칙한 생활/잦은 음주 또는 흡연/과식 및 야식/피로 누적 그리고 현대사회에서 더 부각되는 습관 중 잘못된 비데 사용과  잘못된 좌욕 방법, 그리고 불규칙한 식습관이 있습니다.
#
#
# 치핵(치질)
# 그럼 치핵은 정확히 어떤 것일까요? 보통 치핵과 치질을 헷갈려하시는 분들이 많으신데 치핵 = 치질 같은 말이라고 보시면 됩니다. 보통 이런 치핵에 걸렸음에도 불구하고 대장 쪽 질환은 조금 부끄럽고 민망한 나머지 병원 가시는 걸 하루 이틀 미루시는 분들도 많다고 하네요. 또는 출혈이 적게나마 있음에도 불구하고 자연스레 괜찮아지겠지 라는 안일한 생각이 더 큰 병을 초래할 수 있기 때문에 혈변이 적든 많든 반드시 대장외과 쪽 병원을 가시라고 다시 한번 말씀드릴게요
#
#
# 만약 병원 안가고 방치한다면 암으로 발전까지...
# 대표적으로 혈변을 보는 질환 중에 대장암/치질/치열/궤양성대장염/대장게실 /크론병/직장염/등등의 초기 증상으로 충분히 의심될 수 있기에 초기에 잡아내는 것이 당연히 좋습니다. 더 큰 상황을 만들기보다는 빠른 치료로 평소와 다른 일상생활 복귀를 하시는 것이 좋습니다.
#
#
# 그럼 대장외과병원을 간다면?
# 가장 확실한 병명을 알기 위해서는 대장내시경이 맞겠지만  환자분의 상태를 설명함에 따라 어느 정도 의사분께서 진단을 내릴 수가 있습니다. 예를 들어 피가 나오는 색깔와 양, 그리고  통증과 찢어짐 등으로 항문질환 가능성에 대한 진단을 내려줄겁니다.
#
# 피의 색깔에 따른 의심 증상
#
# 새빨간피가 묻어 나올 경우 출혈 양에 따라 틀리며 간혹 음주나 피곤함에 따라 나오기도 합니다. 하지만 빈도가 많거나 출혈양이 많을 경우 내치핵 증상을 의심해 볼수 있으며 더 나아가 변의 색깔이 검은색이 많이 묻어나올 경우 대장암이나 게실출혈 등 몸안의 직장이나 결장에 이상이 생겼다는 징조일 수도 있기 때문에 더욱 더 정밀검사와 빠른 치료가 요하는 바입니다.
#
#
#
#
#
#
# 공유하기
#
#
#
# 글 요소
#
#
#
# 구독하기
# IT_잡다방
#
#
#
#
#
#
#
#
#
#
#
# 이미지 수 : 10
# img_url: https://t1.daumcdn.net/tistory_admin/static/manage/images/r3/default_L.png
# img_format: PNG
# imge_size: (400, 400)
# os.path.basename(img_url): default_L.png
# len(이미지): 3369
# 1_1_default_L.png
# img_url: https://blog.kakaocdn.net/dn/95545/btqUvDwYcMj/bHRQceepkkYnasBwdFkk9K/img.png
# img_format: PNG
# imge_size: (273, 399)
# os.path.basename(img_url): img.png
# len(이미지): 150207
# 1_2_img.png
# img_url: https://blog.kakaocdn.net/dn/MaoQ7/btqUwzgJFUR/KVDvU1y4U7co4apyEc4MOk/img.png
# img_format: PNG
# imge_size: (389, 383)
# os.path.basename(img_url): img.png
# len(이미지): 163335
# 1_3_img.png
# img_url: https://blog.kakaocdn.net/dn/K2TUy/btqUGTkXBmu/IIH2GBPS9seyUX6EsUeuJ1/img.png
# img_format: PNG
# imge_size: (388, 303)
# os.path.basename(img_url): img.png
# len(이미지): 274529
# 1_4_img.png
# img_url: https://blog.kakaocdn.net/dn/bF2pIP/btqUBwKAtRY/hqaprtw3E01EHCSqlhlSN1/img.png
# img_format: PNG
# imge_size: (519, 341)
# os.path.basename(img_url): img.png
# len(이미지): 283164
# 1_5_img.png
# img_url: https://blog.kakaocdn.net/dn/bB5x1l/btqUtpzuaMb/7suKPA4iofbgBJcCX9RxM1/img.png
# img_format: PNG
# imge_size: (467, 322)
# os.path.basename(img_url): img.png
# len(이미지): 325796
# 1_6_img.png
# img_url: https://blog.kakaocdn.net/dn/bADyYg/btqUsd0o0FE/K8p5AkIDfaqp3Z3IeTMVvK/img.png
# img_format: PNG
# imge_size: (467, 338)
# os.path.basename(img_url): img.png
# len(이미지): 328455
# 1_7_img.png
# img_url: https://blog.kakaocdn.net/dn/cKWGPM/btqUvDwYjvs/sQULOutPI1b8jfCi9gKDk0/img.png
# img_format: PNG
# imge_size: (540, 511)
# os.path.basename(img_url): img.png
# len(이미지): 608874
# 1_8_img.png
# img_url: https://blog.kakaocdn.net/dn/bDie0e/btqUzvypyfg/K883vPbIGKkg6bhAPvK08k/img.png
# img_format: PNG
# imge_size: (388, 289)
# os.path.basename(img_url): img.png
# len(이미지): 270067
# 1_9_img.png
# img_url: https://blog.kakaocdn.net/dn/luEC0/btqUGUqCxiW/SDCml3k2PQlZrNuULCZZI1/img.png
# img_format: PNG
# imge_size: (463, 347)
# os.path.basename(img_url): img.png
# len(이미지): 325842
# 1_10_img.png
